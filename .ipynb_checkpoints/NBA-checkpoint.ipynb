# %% [markdown]
# ## **Future Salary Estimation**
#
# ## Seungri Kim
#
# #### *In this project, our model will assist NBA managers in optimizing player salaries by analyzing how player statistics impacts their contract.*
#
#
# ## **WHY**
#
# #### *The increasing popularity of data and analytics has changed many aspects of the NBA, including roster building and in game strategies. One aspect of the NBA that has remained stagnant is the financial side. Many players are still getting overpaid/underpaid which can negatively affect team and player performance.*
#
# ## **BENEFITS**
#
# #### *As a result of our project, we are hoping that it could help team managers determine a player’s true worth and avoid underpaying or overpaying their players.*
#
# #### *Our model will use basketball data, such as statistics to accurately identify the true value of the player. This will allow NBA managers to give out the most optimal contracts.*

# %%
import numpy as np
import pandas as pd

# %%
#Salary data for 21-22

data_salary_21_22 = pd.read_csv('NBA Salary 21-22.csv')
print(data_salary_21_22.shape)
data_salary_21_22.info()
data_salary_21_22.head()
# Out:
# (481, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RK      481 non-null    int64
#  1   NAME    481 non-null    object
#  2   TEAM    481 non-null    object
#  3   SALARY  481 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.2+ KB
#    RK                   NAME                   TEAM       SALARY
# 0   1      Stephen Curry, PG  Golden State Warriors  $45,780,966
# 1   2       James Harden, SG          Brooklyn Nets  $44,310,840
# 2   3          John Wall, PG        Houston Rockets  $44,310,840
# 3   4  Russell Westbrook, PG     Los Angeles Lakers  $44,211,146
# 4   5       Kevin Durant, PF          Brooklyn Nets  $42,018,900

# %%
#Stats data for 21-22

data_stats_21_22 = pd.read_csv('NBA Stats 21-22.csv')
print(data_stats_21_22.shape)
data_stats_21_22.info()
data_stats_21_22.head()
# Out:
# (448, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 448 entries, 0 to 447
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RANK            0 non-null      float64
#  1   FULL NAME       448 non-null    object
#  2   TEAM            448 non-null    object
#  3   POS             448 non-null    object
#  4   AGE             448 non-null    float64
#  5   GP              448 non-null    int64
#  6   MPG             448 non-null    float64
#  7   MIN%            448 non-null    float64
#  8   USG%            448 non-null    float64
#  9   TO%             434 non-null    float64
#  10  FTA             448 non-null    int64
#  11  FT%             448 non-null    float64
#  12  2PA             448 non-null    int64
#  13  2P%             448 non-null    float64
#  14  3PA             448 non-null    int64
#  15  3P%             448 non-null    float64
# ...

# %%
# cleaning the data, drop the unnecessary columns and get rid of the '$', and position in name on salary data.
# Then mergy stat data and salary data with players name.

def data_cleaning (salary, stats):
    stats = stats.drop(['RANK'], axis=1)
    stats.rename(columns={'FULL NAME': 'NAME'}, inplace=True)
    salary['NAME'] = salary['NAME'].str.split(',').str[0]
    salary['SALARY'] = salary['SALARY'].replace('\$','',regex=True)
    salary['SALARY'] = salary['SALARY'].replace(',','',regex=True)
    #data = stats.join(salary.set_index('NAME'), on='NAME')
    data = stats.merge(salary, on='NAME', how='left')
    data = data.dropna()
    return data

# %%
##Data cleaning and concatenation of salary and stat data(21-22)



data_21_22 = data_cleaning(data_salary_21_22, data_stats_21_22)
# add the year columns
data_21_22['YEAR'] = '21-22'

# %%
data_21_22.info()
data_21_22.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 379 entries, 0 to 482
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            379 non-null    object
#  1   TEAM_x          379 non-null    object
#  2   POS             379 non-null    object
#  3   AGE             379 non-null    float64
#  4   GP              379 non-null    int64
#  5   MPG             379 non-null    float64
#  6   MIN%            379 non-null    float64
#  7   USG%            379 non-null    float64
#  8   TO%             379 non-null    float64
#  9   FTA             379 non-null    int64
#  10  FT%             379 non-null    float64
#  11  2PA             379 non-null    int64
#  12  2P%             379 non-null    float64
#  13  3PA             379 non-null    int64
#  14  3P%             379 non-null    float64
#  15  eFG%            379 non-null    float64
#  16  TS%             379 non-null    float64
# ...

# %%
data_21_22 = data_21_22.astype({"SALARY":'int'})

# %%
# read the csv file (20-21 season record)

data_salary_20_21 = pd.read_csv('NBA Salary 20-21.csv')
data_stats_20_21 = pd.read_csv('NBA Stats 20-21.csv')

# %%
# #Data cleaning and concatenation of salary and stat data(20-21)

data_20_21 = data_cleaning(data_salary_20_21, data_stats_20_21)
# add year
data_20_21['YEAR'] = '20-21'

# %%
data_20_21.info()
data_20_21.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 524 entries, 0 to 625
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            524 non-null    object
#  1   TEAM_x          524 non-null    object
#  2   POS             524 non-null    object
#  3   AGE             524 non-null    float64
#  4   GP              524 non-null    int64
#  5   MPG             524 non-null    float64
#  6   MIN%            524 non-null    float64
#  7   USG%            524 non-null    float64
#  8   TO%             524 non-null    float64
#  9   FTA             524 non-null    int64
#  10  FT%             524 non-null    float64
#  11  2PA             524 non-null    int64
#  12  2P%             524 non-null    float64
#  13  3PA             524 non-null    int64
#  14  3P%             524 non-null    float64
#  15  eFG%            524 non-null    float64
#  16  TS%             524 non-null    float64
# ...

# %%
data_20_21 = data_20_21.astype({"SALARY":'int'}) #To change object type to int
data_20_21['SALARY'] = (data_20_21['SALARY'] * 1.0687) #Inflation
#data_20_21 = data_20_21.astype({"SALARY":'int'}) #To fix scientific notation

# %%
data_20_21
# Out:
#                   NAME TEAM_x  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# 0     Precious Achiuwa    Mia    F  21.66  61  12.1  25.2  19.5  13.5  110
# 2         Steven Adams    Nor    C  27.83  58  27.7  57.6  11.7  17.7  135
# 3          Bam Adebayo    Mia  C-F  23.83  64  34.0  69.7  23.7  15.0  354
# 4    LaMarcus Aldridge    San  C-F  35.83  21  25.9  54.0  22.7   7.0   37
# 5    LaMarcus Aldridge    Bro  C-F  35.83   5  26.0  54.3  19.9  11.8   10
# ..                 ...    ...  ...    ...  ..   ...   ...   ...   ...  ...
# 621       Delon Wright    Sac    G  29.06  27  25.8  53.7  17.1  12.7   36
# 622     Thaddeus Young    Chi    F  32.90  68  24.3  50.6  22.3  16.0  113
# 623         Trae Young    Atl    G  22.66  63  33.7  70.3  33.0  16.2  546
# 624        Cody Zeller    Cha  F-C  28.61  48  20.9  43.6  18.3  11.9  119
# 625        Ivica Zubac    Lac    C  24.16  72  22.3  46.5  15.2  14.7  171
#
#      ...   SPG   BPG  TOPG  VIVersatility    ORTG   DRTG     RK  \
# ...

# %%
#Salary data for 19-20

data_salary_19_20 = pd.read_csv('NBA Salary 19-20.csv')
print(data_salary_19_20.shape)
data_salary_19_20.info()
data_salary_19_20.head()
# Out:
# (528, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RK      528 non-null    int64
#  1   NAME    528 non-null    object
#  2   TEAM    528 non-null    object
#  3   SALARY  528 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 16.6+ KB
#    RK                   NAME                   TEAM       SALARY
# 0   1      Stephen Curry, PG  Golden State Warriors  $40,231,758
# 1   2         Chris Paul, PG  Oklahoma City Thunder  $38,506,482
# 2   3  Russell Westbrook, PG        Houston Rockets  $38,506,482
# 3   4       James Harden, SG        Houston Rockets  $38,199,000
# 4   5       Kevin Durant, PF          Brooklyn Nets  $38,199,000

# %%
#Stats data for 19-20

data_stats_19_20 = pd.read_csv('NBA Stats 19-20.csv')
print(data_stats_19_20.shape)
data_stats_19_20.info()
data_stats_19_20.head()
# Out:
# (591, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 591 entries, 0 to 590
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RANK            0 non-null      float64
#  1   FULL NAME       591 non-null    object
#  2   TEAM            591 non-null    object
#  3   POS             591 non-null    object
#  4   AGE             591 non-null    float64
#  5   GP              591 non-null    int64
#  6   MPG             591 non-null    float64
#  7   MIN%            591 non-null    float64
#  8   USG%            591 non-null    float64
#  9   TO%             589 non-null    float64
#  10  FTA             591 non-null    int64
#  11  FT%             591 non-null    float64
#  12  2PA             591 non-null    int64
#  13  2P%             591 non-null    float64
#  14  3PA             591 non-null    int64
#  15  3P%             591 non-null    float64
# ...

# %%
##Data cleaning and concatenation of salary and stat data(19-20)

data_19_20 = data_cleaning(data_salary_19_20, data_stats_19_20)
data_19_20['YEAR'] = '19-20'

# %%
data_19_20.info()
data_19_20.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 0 to 590
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            499 non-null    object
#  1   TEAM_x          499 non-null    object
#  2   POS             499 non-null    object
#  3   AGE             499 non-null    float64
#  4   GP              499 non-null    int64
#  5   MPG             499 non-null    float64
#  6   MIN%            499 non-null    float64
#  7   USG%            499 non-null    float64
#  8   TO%             499 non-null    float64
#  9   FTA             499 non-null    int64
#  10  FT%             499 non-null    float64
#  11  2PA             499 non-null    int64
#  12  2P%             499 non-null    float64
#  13  3PA             499 non-null    int64
#  14  3P%             499 non-null    float64
#  15  eFG%            499 non-null    float64
#  16  TS%             499 non-null    float64
# ...

# %%
data_19_20 = data_19_20.astype({"SALARY":'int'}) #To change object type to int
data_19_20['SALARY'] = data_19_20['SALARY'] * 1.0123 * 1.0687 #Inflation in salary

# %%
data_19_20 = data_19_20.astype({"SALARY":'int'}) #To remove scientific notation
data_19_20.head()
# Out:
#                        NAME TEAM_x  POS    AGE  GP   MPG  MIN%  USG%   TO%  \
# 0              Steven Adams    Okc    C  27.07  63  26.7  55.6  17.3  14.0
# 1               Bam Adebayo    Mia  C-F  23.08  72  34.0  69.9  21.2  17.5
# 2         LaMarcus Aldridge    San  F-C  35.07  53  33.1  68.9  23.0   7.8
# 4  Nickeil Alexander-Walker    Nor    G  21.95  47  12.6  26.2  23.0  16.1
# 5             Grayson Allen    Mem    G  24.85  38  18.9  39.4  17.6  10.9
#
#    FTA  ...   SPG   BPG  TOPG  VIVersatility    ORTG   DRTG     RK  \
# 0  201  ...  0.81  1.06  1.51             9.2  122.0  101.9   41.0
# 1  382  ...  1.14  1.29  2.82            11.2  116.2  102.2  259.0
# 2  191  ...  0.68  1.64  1.40             8.4  114.7  109.1   40.0
# 4   37  ...  0.36  0.17  1.15             8.5   93.0  106.4  271.0
# 5   45  ...  0.32  0.05  0.87             6.3  113.6  109.0  300.0
#
#                   TEAM_y    SALARY   YEAR
# 0  Oklahoma City Thunder  27957792  19-20
# ...

# %%
#Salary Data for 18-19

data_salary_18_19 = pd.read_csv('NBA Salary 18-19.csv')
print(data_salary_18_19.shape)
data_salary_18_19.info()
data_salary_18_19.head()
# Out:
# (503, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RK      503 non-null    int64
#  1   NAME    503 non-null    object
#  2   TEAM    503 non-null    object
#  3   SALARY  503 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.8+ KB
#    RK                   NAME                   TEAM       SALARY
# 0   1      Stephen Curry, PG  Golden State Warriors  $37,457,154
# 1   2         Chris Paul, PG        Houston Rockets  $35,654,150
# 2   3  Russell Westbrook, PG  Oklahoma City Thunder  $35,654,150
# 3   4       LeBron James, SF     Los Angeles Lakers  $35,654,150
# 4   5      Blake Griffin, PF        Detroit Pistons  $32,088,932

# %%
#Stats data for 18-19

data_stats_18_19 = pd.read_csv('NBA Stats 18-19.csv')
print(data_stats_18_19.shape)
data_stats_18_19.info()
data_stats_18_19.head()
# Out:
# (622, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RANK            0 non-null      float64
#  1   FULL NAME       622 non-null    object
#  2   TEAM            622 non-null    object
#  3   POS             622 non-null    object
#  4   AGE             622 non-null    float64
#  5   GP              622 non-null    int64
#  6   MPG             622 non-null    float64
#  7   MIN%            622 non-null    float64
#  8   USG%            622 non-null    float64
#  9   TO%             616 non-null    float64
#  10  FTA             622 non-null    int64
#  11  FT%             622 non-null    float64
#  12  2PA             622 non-null    int64
#  13  2P%             622 non-null    float64
#  14  3PA             622 non-null    int64
#  15  3P%             622 non-null    float64
# ...

# %%
#Data cleaning and concatenation of salary and stat data(18-19)

data_18_19 = data_cleaning(data_salary_18_19, data_stats_18_19)
data_18_19['YEAR'] = '18-19'

# %%
data_18_19.info()
data_18_19.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 540 entries, 0 to 621
# Data columns (total 32 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NAME            540 non-null    object
#  1   TEAM_x          540 non-null    object
#  2   POS             540 non-null    object
#  3   AGE             540 non-null    float64
#  4   GP              540 non-null    int64
#  5   MPG             540 non-null    float64
#  6   MIN%            540 non-null    float64
#  7   USG%            540 non-null    float64
#  8   TO%             540 non-null    float64
#  9   FTA             540 non-null    int64
#  10  FT%             540 non-null    float64
#  11  2PA             540 non-null    int64
#  12  2P%             540 non-null    float64
#  13  3PA             540 non-null    int64
#  14  3P%             540 non-null    float64
#  15  eFG%            540 non-null    float64
#  16  TS%             540 non-null    float64
# ...

# %%
data_18_19 = data_18_19.astype({"SALARY":'int'}) #Convert type into Int
data_18_19['SALARY'] = data_18_19['SALARY'] * 1.0176 * 1.0123 * 1.0687 #Inflation in salary

# %%
data_18_19 = data_18_19.astype({"SALARY":'int'}) #To remove scientific notation
data_18_19.head()
# Out:
#                 NAME TEAM_x  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  ...  \
# 0       Alex Abrines    Okc    G  25.69  31  19.0  39.5  12.2   7.9   13  ...
# 2       Jaylen Adams    Atl    G  22.93  34  12.6  26.2  13.5  19.7    9  ...
# 3       Steven Adams    Okc    C  25.73  80  33.4  69.5  16.4  12.8  292  ...
# 4        Bam Adebayo    Mia  C-F  21.73  82  23.3  48.6  15.8  17.1  226  ...
# 7  LaMarcus Aldridge    San    F  33.73  81  33.2  69.1  27.0   8.8  412  ...
#
#     SPG   BPG  TOPG  VIVersatility    ORTG   DRTG     RK  \
# 0  0.55  0.19  0.45             3.5  103.1  103.9  185.0
# 2  0.38  0.15  0.82             7.0   99.5  108.1  475.0
# 3  1.49  0.96  1.73             7.1  119.9  102.7   26.0
# 4  0.88  0.79  1.48             9.0  120.0   97.2  256.0
# 7  0.54  1.32  1.78             9.4  117.8  106.4   36.0
#
#                   TEAM_y    SALARY   YEAR
# 0  Oklahoma City Thunder   6005590  18-19
# 2          Atlanta Hawks    297254  18-19
# ...

# %%
# concat all of the data(21-22, 20-21, 19_20, 18_19)

data_18_22 = pd.concat([data_21_22, data_20_21, data_19_20, data_18_19], ignore_index=True)
data_18_22
# Out:
#                    NAME TEAM_x  POS    AGE  GP   MPG  MIN%  USG%   TO%  FTA  \
# 0      Precious Achiuwa    Tor    F  22.15  13  24.1  50.3  19.2  10.6   26
# 1          Steven Adams    Mem    C  28.32  11  25.3  52.8  14.1  17.0   23
# 2           Bam Adebayo    Mia  C-F  24.32  11  32.7  68.2  26.9  15.6   76
# 3          Santi Aldama    Mem  F-C  20.84   3   7.1  14.9  26.0   0.0    3
# 4     LaMarcus Aldridge    Bro  C-F  36.32  11  20.2  42.0  23.3   6.9   22
# ...                 ...    ...  ...    ...  ..   ...   ...   ...   ...  ...
# 1937       Tyler Zeller    Atl    C  29.23   2   5.4  11.1   7.6   0.0    0
# 1938       Tyler Zeller    Mem    C  29.23   4  20.6  42.8  21.7  10.0   18
# 1939         Ante Zizic    Cle    C  22.27  59  18.3  38.2  18.2  13.8  132
# 1940        Ivica Zubac    Lal    C  22.07  33  15.6  32.6  20.5  12.9   66
# 1941        Ivica Zubac    Lac    C  22.07  26  20.1  41.9  20.1  14.8   60
#
# ...

# %%
#Check missing values in the data through heatmap
#Entirely black means no missing value

print("Check the missing values")
sns.heatmap(data_18_22.isnull(), yticklabels = False, cbar = False)
plt.show()

# Print the missing proportion for each column 
data_18_22_ = data_18_22.isnull()

print("The missing Proportion for each column")
for col_name in data_18_22_.columns:
    print(col_name + ": %f " % data_18_22_[col_name].mean())
# Out:
# Check the missing values
# The missing Proportion for each column
# NAME: 0.000000
# TEAM_x: 0.000000
# POS: 0.000000
# AGE: 0.000000
# GP: 0.000000
# MPG: 0.000000
# MIN%: 0.000000
# USG%: 0.000000
# TO%: 0.000000
# FTA: 0.000000
# FT%: 0.000000
# 2PA: 0.000000
# 2P%: 0.000000
# 3PA: 0.000000
# 3P%: 0.000000
# eFG%: 0.000000
# TS%: 0.000000
# PPG: 0.000000
# RPG: 0.000000
# TRB%: 0.000000
# APG: 0.000000
# AST%: 0.000000
# SPG: 0.000000
# BPG: 0.000000
# TOPG: 0.000000
# VIVersatility : 0.000000
# ORTG: 0.000000
# DRTG: 0.000000
# RK: 0.000000
# TEAM_y: 0.000000
# SALARY: 0.000000
# YEAR: 0.000000

# %%
#train test split

from sklearn.model_selection import train_test_split

X = data_18_22.drop(['SALARY'], axis = 1)
y = data_18_22['SALARY']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=88)
X_train.shape, X_test.shape
# Out:
# ((1359, 31), (583, 31))

# %%
#Dropped RK(Salary Ranking), Name, TeamX, Pos, TeamY, Year

col = ['AGE', 'GP', 'MPG', 'MIN%', 'USG%', 'TO%',
       'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', 'eFG%', 'TS%', 'PPG', 'RPG',
       'TRB%', 'APG', 'AST%', 'SPG', 'BPG', 'TOPG', 'VIVersatility ', 'ORTG',
       'DRTG']

X_train1 = X_train[col]
X_test1 = X_test[col]

# %% [markdown]
# ## Random Forest with CV

# %%
#Random Forest with cross validation

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

## using GridSearchCV to find best max_features:

import time
num_feature = len(X_train1.columns)
grid_values = {'max_features': np.linspace(1,num_feature,num_feature, dtype='int32'),
               'min_samples_leaf': [5],
               'n_estimators': [500],
               'random_state': [88]} 

tic = time.time()

rf2 = RandomForestRegressor() 
cv = KFold(n_splits=5,random_state=333,shuffle=True) 
rf_cv = GridSearchCV(rf2, param_grid=grid_values, scoring='r2', cv=cv,verbose=2)
rf_cv.fit(X_train1, y_train)

toc = time.time()

print('time:', round(toc-tic, 2),'s')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88, total=   1.3s
# [CV] max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV]  max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88, total=   0.8s
# [CV] max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88
# [CV]  max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88, total=   0.8s
# [CV] max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88
# [CV]  max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88, total=   0.8s
# [CV] max_features=1, min_samples_leaf=5, n_estimators=500, random_state=88
# ...

# %%
import matplotlib.pyplot as plt
max_features = rf_cv.cv_results_['param_max_features'].data
R2_scores = rf_cv.cv_results_['mean_test_score']

plt.figure(figsize=(8, 6))
plt.xlabel('max features', fontsize=16)
plt.ylabel('CV R2', fontsize=16)
plt.scatter(max_features, R2_scores, s=30)
plt.plot(max_features, R2_scores, linewidth=3)
plt.grid(True, which='both')

# %%
print(rf_cv.best_params_)
# Out:
# {'max_features': 20, 'min_samples_leaf': 5, 'n_estimators': 500, 'random_state': 88}

# %%
def OSR2(model, X_test, y_test, y_train):
    
    y_pred = model.predict(X_test)
    SSE = np.sum((y_test - y_pred)**2)
    SST = np.sum((y_test - np.mean(y_train))**2)
                 
    return (1 - SSE/SST)

# %%
# Model evaluation - Random Forest

print('Cross-validated R2:', round(rf_cv.best_score_, 5))
print('OSR2:', round(OSR2(rf_cv, X_test1, y_test, y_train), 5))
# Out:
# Cross-validated R2: 0.64072
# OSR2: 0.66541

# %%
#To show feature importance

pd.DataFrame({'Feature' : X_train1.columns,  
              'Importance score': 100*rf_cv.best_estimator_.feature_importances_}).round(1)
# Out:
#            Feature  Importance score
# 0              AGE              20.0
# 1               GP               0.8
# 2              MPG               8.2
# 3             MIN%              14.0
# 4             USG%               1.7
# 5              TO%               1.1
# 6              FTA               0.8
# 7              FT%               0.9
# 8              2PA               1.0
# 9              2P%               1.0
# 10             3PA               1.0
# 11             3P%               0.7
# 12            eFG%               0.9
# 13             TS%               0.8
# 14             PPG              28.9
# 15             RPG               1.8
# 16            TRB%               1.1
# 17             APG               1.1
# 18            AST%               1.2
# 19             SPG               1.0
# 20             BPG               1.3
# 21            TOPG               4.6
# 22  VIVersatility                4.0
# 23            ORTG               0.9
# ...

# %%
plt.figure(figsize=(8,7))
plt.barh(X_train1.columns, 100*rf_cv.best_estimator_.feature_importances_)
plt.show()

# %% [markdown]
# ## CART with CV

# %%
#CART with cross validation

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import KFold

grid_values = {'ccp_alpha': np.linspace(0, 0.001, 51)}

dtr = DecisionTreeRegressor(min_samples_leaf=5, min_samples_split=20, random_state=88)
cv = KFold(n_splits=5,random_state=1,shuffle=True) 
dtr_cv = GridSearchCV(dtr, param_grid=grid_values, scoring='r2', cv=cv, verbose=0)
dtr_cv.fit(X_train1, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=1, shuffle=True),
#              estimator=DecisionTreeRegressor(min_samples_leaf=5,
#                                              min_samples_split=20,
#                                              random_state=88),
#              param_grid={'ccp_alpha': array([0.0e+00, 2.0e-05, 4.0e-05, 6.0e-05, 8.0e-05, 1.0e-04, 1.2e-04,
#        1.4e-04, 1.6e-04, 1.8e-04, 2.0e-04, 2.2e-04, 2.4e-04, 2.6e-04,
#        2.8e-04, 3.0e-04, 3.2e-04, 3.4e-04, 3.6e-04, 3.8e-04, 4.0e-04,
#        4.2e-04, 4.4e-04, 4.6e-04, 4.8e-04, 5.0e-04, 5.2e-04, 5.4e-04,
#        5.6e-04, 5.8e-04, 6.0e-04, 6.2e-04, 6.4e-04, 6.6e-04, 6.8e-04,
#        7.0e-04, 7.2e-04, 7.4e-04, 7.6e-04, 7.8e-04, 8.0e-04, 8.2e-04,
#        8.4e-04, 8.6e-04, 8.8e-04, 9.0e-04, 9.2e-04, 9.4e-04, 9.6e-04,
#        9.8e-04, 1.0e-03])},
#              scoring='r2')

# %%
# Graph of cross validated R^2 on each ccp_alpha

ccp_alpha = dtr_cv.cv_results_['param_ccp_alpha'].data
R2_scores = dtr_cv.cv_results_['mean_test_score']

plt.figure(figsize=(8, 6))
plt.xlabel('ccp_alpha', fontsize=16)
plt.ylabel('CV R2', fontsize=16)
plt.scatter(ccp_alpha, R2_scores, s=30)
plt.plot(ccp_alpha, R2_scores, linewidth=3)
plt.grid(True, which='both')
#plt.xlim([0, 0.00055])
#plt.ylim([0.2, 0.5])

plt.tight_layout()
plt.show()

# %%
#Displays the CART tree

from sklearn.tree import plot_tree

print('Node count =', dtr_cv.best_estimator_.tree_.node_count)
plt.figure(figsize=(15, 10))
plot_tree(dtr_cv.best_estimator_, 
          feature_names=X_train1.columns, 
          class_names=['0','1'], 
          filled=True,
          impurity=False,
          fontsize=12,
          max_depth=5) 
plt.show()
# Out:
# Node count = 247

# %%
print('Best ccp_alpha', dtr_cv.best_params_)
# Out:
# Best ccp_alpha {'ccp_alpha': 0.0}

# %%
# Model Evaluation - CART
print('Cross-validated R2:', round(dtr_cv.best_score_, 5))
print('OSR2:', round(OSR2(dtr_cv, X_test1, y_test, y_train), 5))
# Out:
# Cross-validated R2: 0.43588
# OSR2: 0.5383

# %% [markdown]
# ## Bagging with CV

# %%
from sklearn.ensemble import RandomForestRegressor

grid_values = {'min_samples_leaf': [5],
               'n_estimators': [1000],
               'random_state': [88]} 

bagging = RandomForestRegressor(max_features=len(X_train1.columns))
cv = KFold(n_splits=5,random_state=88,shuffle=True) 
bagging_cv = GridSearchCV(bagging, param_grid=grid_values, 
                      scoring='r2', cv=cv,verbose=1).fit(X_train1, y_train)

y_pred_bagging = bagging_cv.predict(X_test1)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.2min finished

# %%
# Model Evaluation
print('Cross-validated R2:', round(bagging_cv.best_score_, 5))
print('OSR2:', round(OSR2(bagging_cv, X_test1, y_test, y_train), 5))
# Out:
# Cross-validated R2: 0.63992
# OSR2: 0.6696

# %% [markdown]
# ## Boosting with CV

# %%
# Boosting with cross validation

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from math import sqrt

grid_values = {'n_estimators':[100,500], 
               'learning_rate': [0.1,0.05,0.02],
               'max_depth':[4], 
               'min_samples_leaf':[3], 
               'max_features':[1.0] } 

gbr = GradientBoostingRegressor() 
cv = KFold(n_splits=5,random_state=88,shuffle=True) 
gbr_cv = GridSearchCV(gbr, param_grid=grid_values, 
                      scoring='r2', cv=cv,verbose=1).fit(X_train1, y_train)

y_pred = gbr_cv.predict(X_test1)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.4min finished

# %%
print(gbr_cv.best_params_)
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'max_features': 1.0, 'min_samples_leaf': 3, 'n_estimators': 100}

# %%
# Model Evaluation - Boosting

rmse = sqrt(mean_squared_error(y_test, y_pred))
mae = mean_absolute_error(y_test, y_pred)

print("Root mean squared error (RMSE) on test set: {:.4f}".format(rmse))
print("The mean absolute error (MAE) on test set: {:.4f}".format(mae))
print('Cross-validated R2:', round(gbr_cv.best_score_, 5))
print('OSR2:', round(OSR2(gbr_cv, X_test1, y_test, y_train), 5))
# Out:
# Root mean squared error (RMSE) on test set: 5526331.2179
# The mean absolute error (MAE) on test set: 3846518.8038
# Cross-validated R2: 0.63691
# OSR2: 0.65675

# %%
# Displays correlation heatmap of features

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = (12,12))
plt.title('Correlation of features', y = 1.05, size = 15)
corr1 = X_train1.corr()

mask1 = np.triu(np.ones_like(corr1, dtype=bool))

sns.heatmap(corr1, mask=mask1)
# Out:
# <AxesSubplot:title={'center':'Correlation of features'}>

# %%
# Feature Selection based on the correlation plot above.

X_train_feature_selection = X_train1.drop(columns = ['TO%', 'TRB%'])
X_test_feature_selection = X_test1.drop(columns = ['TO%', 'TRB%'])

# %%
# Boosting with cross validation after the feature selection

gbr_feature_selection = GradientBoostingRegressor() 
cv = KFold(n_splits=5,random_state=88,shuffle=True) 
gbr_cv_feature_selection = GridSearchCV(gbr_feature_selection, param_grid=grid_values, 
                      scoring='r2', cv=cv,verbose=1).fit(X_train_feature_selection, y_train)

y_pred_feature_selection = gbr_cv_feature_selection.predict(X_test_feature_selection)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:  1.1min finished

# %%
print(gbr_cv_feature_selection.best_params_)
# Out:
# {'learning_rate': 0.05, 'max_depth': 4, 'max_features': 1.0, 'min_samples_leaf': 3, 'n_estimators': 100}

# %%
# Model Evaluation - Boosting (feature selection)

rmse_feature_selection = sqrt(mean_squared_error(y_test, y_pred_feature_selection))
mae_feature_selection = mean_absolute_error(y_test, y_pred_feature_selection)

print("Root mean squared error (RMSE) on test set: {:.4f}".format(rmse_feature_selection ))
print("The mean absolute error (MAE) on test set: {:.4f}".format(mae_feature_selection))
print('Cross-validated R2:', round(gbr_cv_feature_selection.best_score_, 5))
print('OSR2:', round(OSR2(gbr_cv_feature_selection, X_test_feature_selection, y_test, y_train), 5))
# Out:
# Root mean squared error (RMSE) on test set: 5533742.9553
# The mean absolute error (MAE) on test set: 3875148.6222
# Cross-validated R2: 0.64003
# OSR2: 0.65583

# %% [markdown]
# ## Linear Regression

# %%
#VIF function

from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm

def VIF(df, columns):
    values = sm.add_constant(df[columns]).values
    num_columns = len(columns)+1
    vif = [variance_inflation_factor(values, i) for i in range(num_columns)]
    return pd.Series(vif[1:], index=columns)

# %%
#Recombine splitted train and test data
#to use into the data form of smf.ols

X_train_copy = X_train.copy()
X_test_copy = X_test.copy()

X_train_copy['SALARY'] = y_train
X_test_copy['SALARY'] = y_test

train_data = X_train_copy
test_data = X_test_copy

# %% [markdown]
# ### With "Ranking"

# %%
#Linear regression(with Ranking)

import statsmodels.formula.api as smf

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + PPG + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear = ols.fit()
print(linear.summary())

col = ['AGE','GP','MPG','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','PPG','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     192.1
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22697.
# No. Observations:                1359   AIC:                         4.545e+04
# Df Residuals:                    1332   BIC:                         4.559e+04
# Df Model:                          26
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            1.911e+07   3.94e+06      4.852      0.000    1.14e+07    2.68e+07
# ...

# %%
##Linear regression(with Ranking) - without MIN%

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + PPG + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear2 =ols.fit()
print(linear2.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','PPG','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.789
# Model:                            OLS   Adj. R-squared:                  0.785
# Method:                 Least Squares   F-statistic:                     199.3
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22699.
# No. Observations:                1359   AIC:                         4.545e+04
# Df Residuals:                    1333   BIC:                         4.559e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            1.878e+07   3.94e+06      4.767      0.000     1.1e+07    2.65e+07
# ...

# %%
#Linear regression(with Ranking) - without PPG

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear3 =ols.fit()
print(linear3.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.771
# Method:                 Least Squares   F-statistic:                     191.0
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22744.
# No. Observations:                1359   AIC:                         4.554e+04
# Df Residuals:                    1334   BIC:                         4.567e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept             6.26e+06   3.83e+06      1.632      0.103   -1.26e+06    1.38e+07
# ...

# %%
#Linear regression(with Ranking) - without APG

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + RPG + Q("TRB%") + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear4 =ols.fit()
print(linear4.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','RPG','TRB%','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     188.6
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22773.
# No. Observations:                1359   AIC:                         4.559e+04
# Df Residuals:                    1335   BIC:                         4.572e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            5.898e+06   3.92e+06      1.506      0.132   -1.79e+06    1.36e+07
# ...

# %%
#Linear regression(with Ranking) - without RPG

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear5 =ols.fit()
print(linear5.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.763
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     195.8
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22777.
# No. Observations:                1359   AIC:                         4.560e+04
# Df Residuals:                    1336   BIC:                         4.572e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            4.508e+06    3.9e+06      1.157      0.247   -3.13e+06    1.22e+07
# ...

# %%
#Linear regression(with Ranking) - without TOPG

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear6 =ols.fit()
print(linear6.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     195.9
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:00   Log-Likelihood:                -22801.
# No. Observations:                1359   AIC:                         4.565e+04
# Df Residuals:                    1337   BIC:                         4.576e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            3.508e+05   3.92e+06      0.090      0.929   -7.33e+06    8.03e+06
# ...

# %%
#Linear regression(with Ranking) - without 2PA

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + Q("VIVersatility ") + ORTG + DRTG + RK', 
                  data=train_data)
linear7 =ols.fit()
print(linear7.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','VIVersatility ','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.755
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     205.8
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:01   Log-Likelihood:                -22801.
# No. Observations:                1359   AIC:                         4.564e+04
# Df Residuals:                    1338   BIC:                         4.575e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            3.521e+05   3.91e+06      0.090      0.928   -7.31e+06    8.02e+06
# ...

# %%
#Linear regression(with Ranking) - without VIVersatility

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG + RK', 
                  data=train_data)
linear8 =ols.fit()
print(linear8.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     216.5
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:01   Log-Likelihood:                -22802.
# No. Observations:                1359   AIC:                         4.564e+04
# Df Residuals:                    1339   BIC:                         4.575e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9.762e+04    3.9e+06      0.025      0.980   -7.56e+06    7.75e+06
# ...

# %%
#Linear regression(with Ranking) - without TS%

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG + RK', 
                  data=train_data)
linear9 =ols.fit()
print(linear9.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     228.7
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:01   Log-Likelihood:                -22802.
# No. Observations:                1359   AIC:                         4.564e+04
# Df Residuals:                    1340   BIC:                         4.574e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.816e+05   3.88e+06      0.073      0.942   -7.33e+06    7.89e+06
# ...

# %%
#Linear regression(with Ranking) - without 2P%

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("USG%") + Q("TO%") + FTA + Q("FT%")+ Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG + RK', 
                  data=train_data)
linear10 =ols.fit()
print(linear10.summary())

col = ['AGE','GP', 'MPG', 'USG%','TO%','FTA','FT%','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','ORTG','DRTG','RK']
VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     242.3
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:01   Log-Likelihood:                -22802.
# No. Observations:                1359   AIC:                         4.564e+04
# Df Residuals:                    1341   BIC:                         4.573e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2.609e+05   3.88e+06      0.067      0.946   -7.34e+06    7.86e+06
# ...

# %%
#Linear regression(with Ranking) - without FT%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + Q("TO%") + FTA + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG + RK', 
                  data=train_data)
linear12 =ols.fit()
print(linear12.summary())

col = ['AGE','GP', 'USG%','TO%','FTA','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     274.9
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:01   Log-Likelihood:                -22802.
# No. Observations:                1359   AIC:                         4.564e+04
# Df Residuals:                    1343   BIC:                         4.572e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.177e+05   3.78e+06     -0.084      0.933   -7.74e+06     7.1e+06
# ...

# %%
#Linear regression(with Ranking) - without TO%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG + RK', 
                  data=train_data)
linear13 =ols.fit()
print(linear13.summary())

col = ['AGE','GP', 'USG%','FTA','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','ORTG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     294.5
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22802.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1344   BIC:                         4.571e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -1.61e+06   3.44e+06     -0.468      0.640   -8.36e+06    5.14e+06
# ...

# %%
#Linear regression(with Ranking) - without ORTG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG+ DRTG + RK', 
                  data=train_data)
linear14 =ols.fit()
print(linear14.summary())

col = ['AGE','GP', 'USG%','FTA','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     317.3
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22803.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1345   BIC:                         4.571e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.976e+06   3.38e+06     -0.584      0.559   -8.61e+06    4.66e+06
# ...

# %%
#Linear regression(with Ranking) - without eFG%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG + BPG+ DRTG + RK', 
                  data=train_data)
linear15 =ols.fit()
print(linear15.summary())

col = ['AGE','GP', 'USG%','FTA','3PA','3P%','TRB%','AST%','SPG','BPG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     343.8
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22803.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1346   BIC:                         4.570e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.613e+06   3.35e+06     -0.482      0.630   -8.18e+06    4.95e+06
# ...

# %%
#Linear regression(with Ranking) - without BPG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG +DRTG + RK', 
                  data=train_data)
linear16 =ols.fit()
print(linear16.summary())

col = ['AGE','GP', 'USG%','FTA','3PA','3P%','TRB%','AST%','SPG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     375.1
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22803.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1347   BIC:                         4.569e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.567e+06   3.35e+06     -0.469      0.639   -8.13e+06    4.99e+06
# ...

# %%
#Linear regression(with Ranking) - without 3P%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("3PA") + Q("TRB%") + Q("AST%") + SPG +DRTG + RK', 
                  data=train_data)
linear17 =ols.fit()
print(linear17.summary())

col = ['AGE','GP', 'USG%','FTA','3PA','TRB%','AST%','SPG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     412.5
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22804.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1348   BIC:                         4.569e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.761e+06   3.34e+06     -0.527      0.598   -8.31e+06    4.79e+06
# ...

# %%
#Linear regression(with Ranking) - without 3PA

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("USG%") + FTA + Q("TRB%") + Q("AST%") + SPG +DRTG + RK', 
                  data=train_data)
linear18 =ols.fit()
print(linear18.summary())

col = ['AGE','GP', 'USG%','FTA','TRB%','AST%','SPG','DRTG','RK']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.753
# Model:                            OLS   Adj. R-squared:                  0.751
# Method:                 Least Squares   F-statistic:                     457.3
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):               0.00
# Time:                        01:48:02   Log-Likelihood:                -22805.
# No. Observations:                1359   AIC:                         4.563e+04
# Df Residuals:                    1349   BIC:                         4.568e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.243e+06   3.33e+06     -0.673      0.501   -8.78e+06    4.29e+06
# ...

# %%
#Define OSR2 function for linear regression
#because the data used in the linear regression model is not train test splitted data. 

def OSR2_linear(model, df_train, df_test, dependent_var):   
    y_test = df_test[dependent_var]
    y_pred = model.predict(df_test)
    SSE = np.sum((y_test - y_pred)**2)
    SST = np.sum((y_test - np.mean(df_train[dependent_var]))**2)    
    return 1 - SSE/SST

# %%
#print('OSR2:', OSR2_linear(linear17, train_data, test_data, 'SALARY'))
print('OSR2:', OSR2(linear17, X_test, y_test, y_train))
# Out:
# OSR2: 0.7649286022994818

# %% [markdown]
# ### Without Ranking

# %%
#Linear regression(without Ranking)

import statsmodels.formula.api as smf

ols = smf.ols(formula='SALARY ~ AGE + GP + MPG + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + PPG + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear19 = ols.fit()
print(linear19.summary())

col = ['AGE','GP','MPG','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','PPG','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     70.07
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          4.92e-222
# Time:                        01:48:02   Log-Likelihood:                -23186.
# No. Observations:                1359   AIC:                         4.642e+04
# Df Residuals:                    1333   BIC:                         4.656e+04
# Df Model:                          25
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -3.494e+06   5.57e+06     -0.627      0.531   -1.44e+07    7.44e+06
# ...

# %%
#Linear regression(without Ranking) - Without MPG
ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + PPG + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear20 = ols.fit()
print(linear20.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','PPG','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.568
# Model:                            OLS   Adj. R-squared:                  0.560
# Method:                 Least Squares   F-statistic:                     72.97
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          8.63e-223
# Time:                        01:48:03   Log-Likelihood:                -23186.
# No. Observations:                1359   AIC:                         4.642e+04
# Df Residuals:                    1334   BIC:                         4.655e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -3.689e+06   5.57e+06     -0.662      0.508   -1.46e+07    7.24e+06
# ...

# %%
#Linear regression(without Ranking) - Without PPG
ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + RPG + Q("TRB%") + APG + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear21 = ols.fit()
print(linear21.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','RPG','TRB%','APG','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     69.55
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          3.35e-209
# Time:                        01:48:03   Log-Likelihood:                -23221.
# No. Observations:                1359   AIC:                         4.649e+04
# Df Residuals:                    1335   BIC:                         4.661e+04
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -1.991e+07   5.35e+06     -3.721      0.000   -3.04e+07   -9.41e+06
# ...

# %%
#Linear regression(without Ranking) - Without APG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + RPG + Q("TRB%") + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear22 = ols.fit()
print(linear22.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','RPG','TRB%','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.530
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     68.43
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          1.11e-200
# Time:                        01:48:03   Log-Likelihood:                -23243.
# No. Observations:                1359   AIC:                         4.653e+04
# Df Residuals:                    1336   BIC:                         4.665e+04
# Df Model:                          22
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept            -2.07e+07   5.44e+06     -3.808      0.000   -3.14e+07      -1e+07
# ...

# %%
#Linear regression(without Ranking) - Without RPG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + TOPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear23 = ols.fit()
print(linear23.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','TOPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                     70.65
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          2.76e-199
# Time:                        01:48:03   Log-Likelihood:                -23249.
# No. Observations:                1359   AIC:                         4.654e+04
# Df Residuals:                    1337   BIC:                         4.666e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -2.319e+07    5.4e+06     -4.290      0.000   -3.38e+07   -1.26e+07
# ...

# %%
#Linear regression(without Ranking) - Without TOPG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2PA") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear24 = ols.fit()
print(linear24.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2PA','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     69.98
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          1.91e-191
# Time:                        01:48:03   Log-Likelihood:                -23270.
# No. Observations:                1359   AIC:                         4.658e+04
# Df Residuals:                    1338   BIC:                         4.669e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -2.907e+07   5.41e+06     -5.376      0.000   -3.97e+07   -1.85e+07
# ...

# %%
#Linear regression(without Ranking) - Without 2PA

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + Q("VIVersatility ") + ORTG + DRTG', 
                  data=train_data)
linear25 = ols.fit()
print(linear25.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','VIVersatility ','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     73.67
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          2.73e-192
# Time:                        01:48:03   Log-Likelihood:                -23270.
# No. Observations:                1359   AIC:                         4.658e+04
# Df Residuals:                    1339   BIC:                         4.668e+04
# Df Model:                          19
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept           -2.932e+07   5.39e+06     -5.436      0.000   -3.99e+07   -1.87e+07
# ...

# %%
#Linear regression(without Ranking) - Without VIVersatility

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TS%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear26 = ols.fit()
print(linear26.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TS%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.511
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     77.81
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          3.26e-193
# Time:                        01:48:04   Log-Likelihood:                -23270.
# No. Observations:                1359   AIC:                         4.658e+04
# Df Residuals:                    1340   BIC:                         4.668e+04
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.943e+07   5.38e+06     -5.467      0.000      -4e+07   -1.89e+07
# ...

# %%
#Linear regression(without Ranking) - Without TS%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("eFG%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear27 = ols.fit()
print(linear27.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2P%','3PA','3P%','eFG%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     82.26
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          7.50e-194
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.658e+04
# Df Residuals:                    1341   BIC:                         4.667e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.024e+07   5.34e+06     -5.659      0.000   -4.07e+07   -1.98e+07
# ...

# %%
#Linear regression(without Ranking) - Without eFG%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + Q("TO%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear28 = ols.fit()
print(linear28.summary())

col = ['AGE','GP','MIN%','USG%','TO%','FTA','FT%','2P%','3PA','3P%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     87.47
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          7.93e-195
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.658e+04
# Df Residuals:                    1342   BIC:                         4.666e+04
# Df Model:                          16
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -3.015e+07   5.28e+06     -5.716      0.000   -4.05e+07   -1.98e+07
# ...

# %%
#Linear regression(without Ranking) - Without TO%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("FT%") + Q("2P%") + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear29 = ols.fit()
print(linear29.summary())

col = ['AGE','GP','MIN%','USG%','FTA','FT%','2P%','3PA','3P%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     93.36
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          8.16e-196
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1343   BIC:                         4.666e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.983e+07   4.85e+06     -6.155      0.000   -3.93e+07   -2.03e+07
# ...

# %%
#Linear regression(without Ranking) - Without FT%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("2P%") + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear30 = ols.fit()
print(linear30.summary())

col = ['AGE','GP','MIN%','USG%','FTA','2P%','3PA','3P%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     100.1
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          9.29e-197
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1344   BIC:                         4.665e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.968e+07   4.84e+06     -6.136      0.000   -3.92e+07   -2.02e+07
# ...

# %%
#Linear regression(without Ranking) - Without 2P%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("3PA") + Q("3P%") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear31 = ols.fit()
print(linear31.summary())

col = ['AGE','GP','MIN%','USG%','FTA','3PA','3P%','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     107.8
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          1.07e-197
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1345   BIC:                         4.664e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.975e+07   4.84e+06     -6.152      0.000   -3.92e+07   -2.03e+07
# ...

# %%
#Linear regression(without Ranking) - Without 3P%

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("3PA") + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear32 = ols.fit()
print(linear32.summary())

col = ['AGE','GP','MIN%','USG%','FTA','3PA','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     116.7
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          1.63e-198
# Time:                        01:48:04   Log-Likelihood:                -23271.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1346   BIC:                         4.664e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -2.98e+07   4.84e+06     -6.164      0.000   -3.93e+07   -2.03e+07
# ...

# %%
#Linear regression(without Ranking) - Without 3PA

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("TRB%") + Q("AST%") + SPG + BPG + ORTG + DRTG', 
                  data=train_data)
linear33 = ols.fit()
print(linear33.summary())

col = ['AGE','GP','MIN%','USG%','FTA','TRB%','AST%','SPG','BPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.506
# Method:                 Least Squares   F-statistic:                     127.2
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          2.19e-199
# Time:                        01:48:04   Log-Likelihood:                -23272.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1347   BIC:                         4.663e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.988e+07   4.83e+06     -6.182      0.000   -3.94e+07   -2.04e+07
# ...

# %%
#Linear regression(without Ranking) - Without BPG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("TRB%") + Q("AST%") + SPG + ORTG + DRTG', 
                  data=train_data)
linear34 = ols.fit()
print(linear34.summary())

col = ['AGE','GP','MIN%','USG%','FTA','TRB%','AST%','SPG','ORTG','DRTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     139.7
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          3.67e-200
# Time:                        01:48:04   Log-Likelihood:                -23273.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1348   BIC:                         4.662e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.963e+07   4.83e+06     -6.135      0.000   -3.91e+07   -2.02e+07
# ...

# %%
#Linear regression(without Ranking) - Without DRTG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("TRB%") + Q("AST%") + SPG + ORTG', 
                  data=train_data)
linear35 = ols.fit()
print(linear35.summary())

col = ['AGE','GP','MIN%','USG%','FTA','TRB%','AST%','SPG','ORTG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.508
# Model:                            OLS   Adj. R-squared:                  0.505
# Method:                 Least Squares   F-statistic:                     154.9
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          8.25e-201
# Time:                        01:48:05   Log-Likelihood:                -23274.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1349   BIC:                         4.662e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -2.327e+07   2.08e+06    -11.174      0.000   -2.74e+07   -1.92e+07
# ...

# %%
#Linear regression(without Ranking) - Without ORTG

ols = smf.ols(formula='SALARY ~ AGE + GP + Q("MIN%") + Q("USG%") + FTA + Q("TRB%") + Q("AST%") + SPG', 
                  data=train_data)
linear36 = ols.fit()
print(linear36.summary())

col = ['AGE','GP','MIN%','USG%','FTA','TRB%','AST%','SPG']

VIF(train_data, col)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 SALARY   R-squared:                       0.507
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     173.7
# Date:                Wed, 08 Dec 2021   Prob (F-statistic):          2.48e-201
# Time:                        01:48:05   Log-Likelihood:                -23275.
# No. Observations:                1359   AIC:                         4.657e+04
# Df Residuals:                    1350   BIC:                         4.662e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -2.56e+07   1.56e+06    -16.393      0.000   -2.87e+07   -2.25e+07
# ...

# %%
#Here we can use OSR2 function becuase RK is removed from X_test1 and train_data

print('OSR2:', OSR2(linear36, X_test1, y_test, y_train))
#print('OSR2:', OSR2_linear(linear36, train_data, test_data, 'SALARY'))
# Out:
# OSR2: 0.5096339917582419

# %% [markdown]
# ## Model Comparison

# %%
#Model comparison - Random Forest, CART, Bagging, Boosting, Linear Regression

comparison_data = {'Random Forest': ['{:.4f}'.format(OSR2(rf_cv, X_test1, y_test, y_train))],
                   'CART': ['{:.4f}'.format(OSR2(dtr_cv, X_test1, y_test, y_train))],
                   'Bagging': ['{:.4f}'.format(OSR2(bagging_cv, X_test1, y_test, y_train))],
                   #'Boosting': ['{:.4f}'.format(OSR2(gbr_cv, X_test1, y_test, y_train))],
                   'Boosting': ['{:.4f}'.format(OSR2(gbr_cv_feature_selection, X_test_feature_selection, y_test, y_train))],
                   'Linear Regression': ['{:.4f}'.format(OSR2_linear(linear36, train_data, test_data,'SALARY'))]
                  }

comparison_table = pd.DataFrame(data=comparison_data, 
                                index=['OSR2'])
comparison_table.style.set_properties(
    **{'font-size': '12pt',}).set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '10pt')]}])
# Out:
# <style  type="text/css" >
#     #T_f11f1808_580b_11ec_8ab5_3af9d3608cbc th {
#           font-size: 10pt;
#     }#T_f11f1808_580b_11ec_8ab5_3af9d3608cbcrow0_col0,#T_f11f1808_580b_11ec_8ab5_3af9d3608cbcrow0_col1,#T_f11f1808_580b_11ec_8ab5_3af9d3608cbcrow0_col2,#T_f11f1808_580b_11ec_8ab5_3af9d3608cbcrow0_col3,#T_f11f1808_580b_11ec_8ab5_3af9d3608cbcrow0_col4{
#             font-size:  12pt;
#         }</style><table id="T_f11f1808_580b_11ec_8ab5_3af9d3608cbc" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Random Forest</th>        <th class="col_heading level0 col1" >CART</th>        <th class="col_heading level0 col2" >Bagging</th>        <th class="col_heading level0 col3" >Boosting</th>        <th class="col_heading level0 col4" >Linear Regression</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f11f1808_580b_11ec_8ab5_3af9d3608cbclevel0_row0" class="row_heading level0 row0" >OSR2</th>
# ...

# %% [markdown]
# ## Model Comparison through Bootstrapping

# %%
#pip install bootstrapped

# %%
import numpy as np
import bootstrapped.bootstrap as bs
import bootstrapped.stats_functions as bs_stats

# %%
#Define metric functions to use in bootstrap

def OS_R_squared(predictions, y_test,y_train):
    SSE = np.sum((y_test-predictions)**2)
    SST = np.sum((y_test-np.mean(y_train))**2)
    r2 = 1-SSE/SST
    return r2

def mean_squared_error(predictions, y_test,y_train):
    MSE = np.mean((y_test-predictions)**2)
    return MSE

def mean_absolute_error(predictions, y_test,y_train):
    MAE = np.mean(np.abs(y_test-predictions))
    return MAE

# %%
#Bootstrap function for model comparison

def bootstrap_validation(test_data, test_label, train_label,
                         model0,model1,model2,model3,model4,
                         metrics_list, sample=500, random_state=66):
    n_sample = sample
    n_metrics = len(metrics_list)
    output_array1=np.zeros([n_sample, n_metrics])
    output_array1[:]=np.nan
    output_array2=np.zeros([n_sample, n_metrics])
    output_array2[:]=np.nan
    output_array3=np.zeros([n_sample, n_metrics])
    output_array3[:]=np.nan
    output_array4=np.zeros([n_sample, n_metrics])
    output_array4[:]=np.nan
    #print(output_array.shape)
    
    for bs_iter in range(n_sample):
        bs_index = np.random.choice(test_data.index, len(test_data.index), replace=True)
        bs_data = test_data.loc[bs_index]
        bs_label = test_label.loc[bs_index]
        bs_data_gbr = bs_data.drop(columns = ['TO%', 'TRB%'])
      
        bs_predicted_bagging = model0.predict(bs_data)
        
        bs_predicted1 = model1.predict(bs_data)
        bs_predicted2 = model2.predict(bs_data)
        bs_predicted3 = model3.predict(bs_data_gbr)
        bs_predicted4 = model4.predict(bs_data)
        
        for metrics_iter in range(n_metrics):
            metrics = metrics_list[metrics_iter]
            output_array1[bs_iter, metrics_iter]=metrics(bs_predicted1,bs_label,train_label)-metrics(bs_predicted_bagging,bs_label,train_label)
            output_array2[bs_iter, metrics_iter]=metrics(bs_predicted2,bs_label,train_label)-metrics(bs_predicted_bagging,bs_label,train_label)
            output_array3[bs_iter, metrics_iter]=metrics(bs_predicted3,bs_label,train_label)-metrics(bs_predicted_bagging,bs_label,train_label)
            output_array4[bs_iter, metrics_iter]=metrics(bs_predicted4,bs_label,train_label)-metrics(bs_predicted_bagging,bs_label,train_label)
            
    output_df1 = pd.DataFrame(output_array1)
    output_df2 = pd.DataFrame(output_array2)
    output_df3 = pd.DataFrame(output_array3)
    output_df4 = pd.DataFrame(output_array4)
    
    return output_df1, output_df2, output_df3, output_df4

# %%
bs_output1, bs_output2, bs_output3, bs_output4 = bootstrap_validation(X_test1, y_test, y_train,
                                                          bagging_cv, rf_cv, dtr_cv, gbr_cv_feature_selection, linear36,
                                                          metrics_list=[OS_R_squared],
                                                          sample = 5000)

# %%
#Model comparison - (RF OSR^2 - Bagging OSR^2)

fig, axs = plt.subplots(ncols=1, figsize=(8,5))
axs.set_xlabel('RF OSR^2 - Bagging OSR^2', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output1.iloc[:,0], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output1.iloc[:,0], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output1.iloc[:,0], 0.975), ymin = 0, ymax =800, color = "black")

# %%
#Model comparison - (CART OSR^2 - Bagging OSR^2)

fig, axs = plt.subplots(ncols=1, figsize=(8,5))
axs.set_xlabel('CART OSR^2 - Bagging OSR^2', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output2.iloc[:,0], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output2.iloc[:,0], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output2.iloc[:,0], 0.975), ymin = 0, ymax =800, color = "black")

# %%
#Model comparison - (Boosting OSR^2 - Bagging OSR^2)

fig, axs = plt.subplots(ncols=1, figsize=(8,5))
axs.set_xlabel('Gradient Boosting OSR^2 - Bagging OSR^2', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output3.iloc[:,0], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output3.iloc[:,0], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output3.iloc[:,0], 0.975), ymin = 0, ymax =800, color = "black")

# %%
#Model comparison - (Linear Regression OSR^2 - Bagging OSR^2)

fig, axs = plt.subplots(ncols=1, figsize=(8,5))
axs.set_xlabel('Linear Regression OSR^2 - Bagging OSR^2', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output4.iloc[:,0], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output4.iloc[:,0], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output4.iloc[:,0], 0.975), ymin = 0, ymax =800, color = "black")

# %%
#Bootstrapping metrics of the best model

def bootstrap_best(test_data, test_label, train_label, model, 
                   metrics_list, sample=500, random_state=66):
    n_sample = sample
    n_metrics = len(metrics_list)
    output_array=np.zeros([n_sample, n_metrics])
    output_array[:]=np.nan
    print(output_array.shape)
    for bs_iter in range(n_sample):
        bs_index = np.random.choice(test_data.index, len(test_data.index), replace=True)
        bs_data = test_data.loc[bs_index]
        bs_label = test_label.loc[bs_index]
        bs_predicted = model.predict(bs_data)
        for metrics_iter in range(n_metrics):
            metrics = metrics_list[metrics_iter]
            output_array[bs_iter, metrics_iter]=metrics(bs_predicted,bs_label,train_label)
    output_df = pd.DataFrame(output_array)
    return output_df

# %%
bs_output_best_bagging = bootstrap_best(X_test1,y_test,y_train, bagging_cv,
                                 metrics_list=[OS_R_squared, mean_squared_error, mean_absolute_error],
                                 sample = 5000)
# Out:
# (5000, 3)

# %%
#Bootstrap bagging OSR^2

y_pred_bagging = bagging_cv.predict(X_test1)
test_osr = OS_R_squared(y_pred_bagging,y_test,y_train)

fig, axs = plt.subplots(ncols=1, figsize=(8,6))
axs.set_xlabel('Bootstrap bagging OSR^2', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output_best_bagging.iloc[:,0], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,0], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,0], 0.975), ymin = 0, ymax =800, color = "black")

print("The test-set OSR^2 is %s " % test_osr)
print("The 95-percent confidence interval of bagging OSR^2 is %s" % 
      np.quantile(bs_output_best_bagging.iloc[:,0], 0.025),np.quantile(bs_output_best_bagging.iloc[:,0], 0.975))
# Out:
# The test-set OSR^2 is 0.6695960754084667
# The 95-percent confidence interval of bagging OSR^2 is 0.6007596887774002 0.7278601232090295

# %%
#Bootstrap bagging MSE

test_mse = mean_squared_error(y_pred_bagging,y_test,y_train)

fig, axs = plt.subplots(ncols=1, figsize=(8,6))
axs.set_xlabel('Bootstrap bagging MSE', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output_best_bagging.iloc[:,1], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,1], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,1], 0.975), ymin = 0, ymax =800, color = "black")

print("The test-set MSE is %s " % test_mse)
print("The 95-percent confidence interval of bagging MSE is %s" % 
      np.quantile(bs_output_best_bagging.iloc[:,1], 0.025),np.quantile(bs_output_best_bagging.iloc[:1], 0.975))
# Out:
# The test-set MSE is 29397480318829.97
# The 95-percent confidence interval of bagging MSE is 24805279710876.273 28782985102232.04

# %%
#Bootstrap bagging MAE

test_mae = mean_absolute_error(y_pred_bagging,y_test,y_train)

fig, axs = plt.subplots(ncols=1, figsize=(8,6))
axs.set_xlabel('Bootstrap bagging MAE', fontsize=16)
axs.set_ylabel('Count', fontsize=16)
axs.hist(bs_output_best_bagging.iloc[:,2], bins=20,edgecolor='green', linewidth=2,color = "grey")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,2], 0.025), ymin = 0, ymax =800, color = "black")
axs.vlines(x=np.quantile(bs_output_best_bagging.iloc[:,2], 0.975), ymin = 0, ymax =800, color = "black")

print("The test-set MAE is %s " % test_mae)
print("The 95-percent confidence interval of bagging MAE is %s" % 
      np.quantile(bs_output_best_bagging.iloc[:,2], 0.025),np.quantile(bs_output_best_bagging.iloc[:2], 0.975))
# Out:
# The test-set MAE is 3813920.6558168936
# The 95-percent confidence interval of bagging MAE is 3508632.000625292 29756967980575.14
